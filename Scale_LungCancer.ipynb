# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanhnhat1211/Bai-Tap-AI/blob/main/Scale_LungCancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'lung_cancer_examples.csv'
data = pd.read_csv(url)
data.head()

del data['Name']
del data['Surname']
data.head()

from sklearn import datasets
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

x = data.loc[:,['Age','Smokes','AreaQ','Alkhol']]
y = data.loc[:,['Result']]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

print(x_train,x_train_std)

from sklearn import datasets
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

x = data.loc[:,['Age','Smokes','AreaQ','Alkhol']]
y = data.loc[:,['Result']]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

sc = StandardScaler()
sc.fit(x_train)
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

print(x_train,x_train_std)
model = Perceptron(max_iter = 1000, eta0=0.05,random_state = 0)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print(y_pred)
print(y_test)
print('Đo chinh xac ma hinh chua scale:',accuracy_score(y_test,y_pred))

model = Perceptron(max_iter = 1000, eta0 = 0.05,random_state = 0)
model.fit(x_train_std,y_train)
y_pred = model.predict(x_test_std)
print(y_pred)
print(y_test)
print('Do chinh xac ma hinh chua scale:',accuracy_score(y_test,y_pred))
# Out:
#     Age  Smokes  AreaQ  Alkhol
# 9    52      18      4       5
# 13   28      20      2       8
# 41   47      12      8       0
# 40   50      20      2       4
# 31   56      20      3       3
# 10   33       4      8       0
# 7    22      12      5       2
# 55   77      20      5       4
# 5    34       0     10       0
# 42   69      20      5       4
# 29   40      20      2       7
# 32   47      15      1       8
# 46   31      20      9       4
# 33   62      25      3       4
# 45   21      20      8       3
# 43   63      20      4       5
# 39   37      10      5       3
# 44   39      15      7       2
# 14   34      25      4       8
# 51   44      30      1       6
# 11   18      10      6       3
# 37   62      15      5       5
# 47   28      10      4       1
# 4    68       4      5       6
# 34   26      10      7       2
# 21   33       8      8       1
# 8    45       2      6       0
# 36   59      20      3       4
# 1    27      20      2       5
# ...
